# %%
#importing all required libraries
import pandas as pd
import numpy as np
import scipy as sp
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#loading and preprocessing data
df = pd.read_csv("Datasets/Regression/Boston.csv", index_col=0)
df.columns = df.columns.str.lower()
print(df.shape)
df.head()
# Out:
# (506, 14)
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 1  396.90   4.98  24.0
# 2  396.90   9.14  21.6
# 3  392.83   4.03  34.7
# 4  394.63   2.94  33.4
# 5  396.90   5.33  36.2

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1:]
X_train, X_test, y_train, y_test = train_test_split(X, y)
X_train.head()
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 90   0.05302  0.0   3.41     0  0.489  7.079   63.1  3.4145    2  270
# 346  0.03113  0.0   4.39     0  0.442  6.014   48.5  8.0136    3  352
# 458  8.20058  0.0  18.10     0  0.713  5.936   80.3  2.7792   24  666
# 167  2.01019  0.0  19.58     0  0.605  7.929   96.2  2.0459    5  403
# 146  2.37934  0.0  19.58     0  0.871  6.130  100.0  1.4191    5  403
#
#      ptratio   black  lstat
# 90      17.8  396.06   5.70
# 346     18.8  385.64  10.53
# 458     20.2    3.50  16.94
# 167     14.7  369.30   3.70
# 146     14.7  172.91  27.80

# %%
#linear regression from scratch
#X and y including their train test splits have already been made during the preprocessing step
def createWeightsAndBias(X):
    W = np.random.randn(X.shape[1])
    B = np.random.randn()
    print(W, B)
    return W, B


def updateWeights(X, y, W, B, alpha = 0.001):
    indices = [i for i in range(X.shape[0])]
    np.random.shuffle(indices)
    cost = 0
    for i in indices:
        yhat = np.dot(X[i], W) + B
        cost += ((yhat-y[i])**2)/2
        for j in range(X.shape[1]):
            W[j] -= alpha*((yhat - y[i])*X[i][j])
        B -= alpha*((yhat - y[i]))
    return W, B, cost

def train(X, y, epochs = 10):
    W, B = createWeightsAndBias(X)
    lossDuringTraining = []
    epoch = [0]
    #lossDuringTraining.append(np.sum(((np.dot(X, W)+B-y)**2)/2))
    for j in range(epochs):
        W, B, temp = updateWeights(X, y, W, B)
        print(W, B, temp)
        #lossDuringTraining.append(temp)
        #epoch.append(j)
    return W, B, lossDuringTraining, epoch

# %%
W, B = createWeightsAndBias(X_train)
print(W,B)
print(X_train.shape[1])
X_train[0, :].reshape
# Out:
# [-1.62376291  0.81487941  0.15685237 -0.62601869  1.84402997 -0.78147745
#  -0.89584162 -0.79815322  2.40492367 -1.45217063  1.10716838  0.40099089
#  -0.18799758] -0.003338623682251353
# [-1.62376291  0.81487941  0.15685237 -0.62601869  1.84402997 -0.78147745
#  -0.89584162 -0.79815322  2.40492367 -1.45217063  1.10716838  0.40099089
#  -0.18799758] -0.003338623682251353
# 13
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7320\1746892211.py in ?()
#       1 W, B = createWeightsAndBias(X_train)
#       2 print(W,B)
#       3 print(X_train.shape[1])
# ----> 4 X_train.reshape()
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
# ...

# %%
cost = 0
alpha = 0.001
print(W,B)
for i in range(X_train.shape[0]):
    index = np.random.randint(1, X_train.shape[0])
    xi = X_train[index, :].reshape(1, X_train.shape[1])
    yi = y_train[index]
    yhat = np.dot(X[i], W) + B
    print(f"yhat = {yhat}")
    cost += ((yhat-y[i])**2)/2
    print(f"cost: {cost}")
    for j in range(X_train.shape[1]):
        W[j] -= alpha*((yhat - y[i])*X[i][j])
        print(f"W[{j}] = {W[j]}")
        break
    B -= alpha*((yhat - y[i]))
    print(f"B {B}")
    break

print(W, B)
# Out:
# [ 0.6763035  -1.00479063  0.44170854  1.32561196 -0.24412975 -1.03098049
#  -0.27719341 -0.81488166 -0.62738214  0.72446276 -0.98006054 -2.46031793
#   1.23195201] -0.4981753439447663
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (139, slice(None, None, None))
#
# ...
